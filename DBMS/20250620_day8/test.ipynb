# %%
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.example_db
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'example_db')

# %%
collection = db.example_collection
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'example_db'), 'example_collection')

# %%
example_document = [{"name" : "lee",  "age" : 32 , "city" : "Daegu"},
                    {"name" : "lee", "age" : 22, "city" : "Seoul"}]
collection.insert_many(example_document)
# Out:
# InsertManyResult([ObjectId('68552dfcf6cf0425310a786c'), ObjectId('68552dfcf6cf0425310a786d')], acknowledged=True)

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('68552b04f6cf0425310a7864'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552b04f6cf0425310a7865'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552df9f6cf0425310a7866'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552df9f6cf0425310a7867'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfbf6cf0425310a7868'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfbf6cf0425310a7869'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfbf6cf0425310a786a'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfbf6cf0425310a786b'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfcf6cf0425310a786c'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfcf6cf0425310a786d'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}

# %%
query = {"city" : "Daegu"}

for doc in collection.find(query):
    print(doc)
# Out:
# {'_id': ObjectId('68552b04f6cf0425310a7864'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}

# %%
collection.update_one({"name":"lee"},{"$set" : {"age" : 33}})

for data in collection.find():
    print(data)
# Out:
# {'_id': ObjectId('68552b04f6cf0425310a7864'), 'name': 'lee', 'age': 33, 'city': 'Daegu'}
# {'_id': ObjectId('68552b04f6cf0425310a7865'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552df9f6cf0425310a7866'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552df9f6cf0425310a7867'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfbf6cf0425310a7868'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfbf6cf0425310a7869'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfbf6cf0425310a786a'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfbf6cf0425310a786b'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
# {'_id': ObjectId('68552dfcf6cf0425310a786c'), 'name': 'lee', 'age': 32, 'city': 'Daegu'}
# {'_id': ObjectId('68552dfcf6cf0425310a786d'), 'name': 'lee', 'age': 22, 'city': 'Seoul'}
